# %% [markdown]
# <a href="https://colab.research.google.com/github/Anashrah/jupyter-exploration/blob/main/My_First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My First Jupyter Notebook
#
# This notebook was created using Google Colab.
#
# # Objectives
# In this lab, I explored the following concepts:
#
# 1. Creating and formatting Markdown cells
# 2. Writing and executing Python code
# 3. Understanding how Jupyter Notebooks work
# 4. Connecting Google Colab to GitHub

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Anashrah Adil"
course = "Comp Vision-Artificial Intel-22600ITAI-1378"
print(name)
print(course)
# Out:
# Anashrah Adil
# Comp Vision-Artificial Intel-22600ITAI-1378

# %%
print("My first lab assignment")
# Out:
# My first lab assignment

# %%
x=5
y=3
print("Sum x + y=", x+y )
# Out:
# Sum x + y= 8
